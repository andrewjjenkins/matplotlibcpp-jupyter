// %%
#include "xplot/xfigure.hpp"
#include "xplot/xmarks.hpp"
#include "xplot/xaxes.hpp"
// Out:
// In file included from input_line_7:1:
// In file included from /micromamba/envs/xplot/include/xplot/xfigure.hpp:23:
// /micromamba/envs/xplot/include/xplot/xaxes.hpp:42:39: error: expected ';' after alias declaration
//         using scale_type = xw::xholder<xscale>;
//                                       ^
//                                       ;
// In file included from input_line_7:1:
// In file included from /micromamba/envs/xplot/include/xplot/xfigure.hpp:24:
// /micromamba/envs/xplot/include/xplot/xmarks.hpp:64:64: error: expected '>'
//     using xmark_scales_type = std::map<std::string, xw::xholder<xscale>>;
//                                                                ^
// /micromamba/envs/xplot/include/xplot/xmarks.hpp:64:64: error: expected ';' after alias declaration
//     using xmark_scales_type = std::map<std::string, xw::xholder<xscale>>;
//                                                                ^
//                                                                ;
// /micromamba/envs/xplot/include/xplot/xmarks.hpp:65:43: error: expected ';' after alias declaration
//     using xmark_tooltip_type = xw::xholder<xw::xwidget>;
//                                           ^
//                                           ;
// /micromamba/envs/xplot/include/xplot/xmarks.hpp:75:29: error: unknown type name 'xmark_scales_type'
//         using scales_type = xmark_scales_type;
//                             ^
// /micromamba/envs/xplot/include/xplot/xmarks.hpp:84:19: error: use of undeclared identifier 'scales_type'
//         XPROPERTY(scales_type, derived_type, scales);
//                   ^
// In file included from input_line_7:1:
// /micromamba/envs/xplot/include/xplot/xfigure.hpp:44:50: error: expected '>'
//         using axes_type = std::vector<xw::xholder<xaxis>>;
//                                                  ^
// /micromamba/envs/xplot/include/xplot/xfigure.hpp:44:50: error: expected ';' after alias declaration
//         using axes_type = std::vector<xw::xholder<xaxis>>;
//                                                  ^
//                                                  ;
// /micromamba/envs/xplot/include/xplot/xfigure.hpp:45:51: error: expected '>'
//         using marks_type = std::vector<xw::xholder<xmark>>;
//                                                   ^
// /micromamba/envs/xplot/include/xplot/xfigure.hpp:45:51: error: expected ';' after alias declaration
//         using marks_type = std::vector<xw::xholder<xmark>>;
//                                                   ^
//                                                   ;
// /micromamba/envs/xplot/include/xplot/xfigure.hpp:46:40: error: expected ';' after alias declaration
//         using scales_type = xw::xholder<xscale>;
//                                        ^
//                                        ;
// /micromamba/envs/xplot/include/xplot/xfigure.hpp:47:45: error: expected ';' after alias declaration
//         using interaction_type = xw::xholder<xinteraction>;
//                                             ^
//                                             ;
// /micromamba/envs/xplot/include/xplot/xfigure.hpp:53:19: error: use of undeclared identifier 'axes_type'
//         XPROPERTY(axes_type, derived_type, axes);
//                   ^
// /micromamba/envs/xplot/include/xplot/xfigure.hpp:54:19: error: use of undeclared identifier 'marks_type'
//         XPROPERTY(marks_type, derived_type, marks);
//                   ^
// /micromamba/envs/xplot/include/xplot/xfigure.hpp:176:40: error: 'make_id_holder' does not name a template but is followed by template arguments; did you mean 'make_weak_holder'?
//         this->marks().emplace_back(xw::make_id_holder<xmark>(w.id()));
//                                        ^
// /micromamba/envs/xplot/include/xwidgets/xholder.hpp:314:13: note: 'make_weak_holder' declared here
//     xholder make_weak_holder(xtransport<D>* ptr)
//             ^
// /micromamba/envs/xplot/include/xwidgets/xholder.hpp:103:26: note: non-template declaration found by name lookup
//     XWIDGETS_API xholder make_id_holder(xeus::xguid id);
//                          ^
// In file included from input_line_7:1:
// /micromamba/envs/xplot/include/xplot/xfigure.hpp:203:39: error: expected ')'
//                 [&w](const xw::xholder<xmark>& element) {
//                                       ^
// /micromamba/envs/xplot/include/xplot/xfigure.hpp:203:21: note: to match this '('
//                 [&w](const xw::xholder<xmark>& element) {
//                     ^
// /micromamba/envs/xplot/include/xplot/xfigure.hpp:204:28: error: use of undeclared identifier 'element'
//                     return element.id() == w.id();
//                            ^
// /micromamba/envs/xplot/include/xplot/xfigure.hpp:223:39: error: 'make_id_holder' does not name a template but is followed by template arguments; did you mean 'make_weak_holder'?
//         this->axes().emplace_back(xw::make_id_holder<xaxis>(w.id()));
//                                       ^
// /micromamba/envs/xplot/include/xwidgets/xholder.hpp:314:13: note: 'make_weak_holder' declared here
//     xholder make_weak_holder(xtransport<D>* ptr)
//             ^
// /micromamba/envs/xplot/include/xwidgets/xholder.hpp:103:26: note: non-template declaration found by name lookup
//     XWIDGETS_API xholder make_id_holder(xeus::xguid id);
//                          ^
// In file included from input_line_7:1:
// /micromamba/envs/xplot/include/xplot/xfigure.hpp:250:39: error: expected ')'
//                 [&w](const xw::xholder<xaxis>& element) {
//                                       ^
// /micromamba/envs/xplot/include/xplot/xfigure.hpp:250:21: note: to match this '('
//                 [&w](const xw::xholder<xaxis>& element) {
//                     ^
// fatal error: too many errors emitted, stopping now [-ferror-limit=]
// Interpreter Error:

// %%
std::size_t n = 1000;

// %%
#include <random>

std::random_device rd;  
std::mt19937 gen(rd());
std::normal_distribution<> d(5,2);

// %%
std::vector<double> y(n);

// %%
for(std::size_t i=0; i<n; ++i)
{
    y[i] = d(gen);
}

// %%
xpl::linear_scale xs, ys;
// Out:
// input_line_20:2:2: error: use of undeclared identifier 'xpl'; did you mean 'xtl'?
//  xpl::linear_scale xs, ys;
//  ^~~
//  xtl
// /micromamba/envs/xplot/include/xtl/xbasic_fixed_string.hpp:715:11: note: 'xtl' declared here
// namespace xtl
//           ^
// input_line_20:2:7: error: no type named 'linear_scale' in namespace 'xtl'
//  xpl::linear_scale xs, ys;
//  ~~~~~^
// Interpreter Error:

// %%
xpl::figure fig;
fig
// Out:
